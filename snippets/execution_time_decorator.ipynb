# %% [markdown]
# # Detailed execution time for cadCAD models
#
# *Danilo Lessa Bernardineli*
#
# ---
#
# This notebook shows how you can get detailed info about the execution time by using Python decorators on the minimal P&P model. The strategy is to make use of the decorator as defined in the next block, and use in the most convenient way.
#
# There are two options: one is to make use of the decorator on the function definition, like by wrapping the `p_predator_births` and the `p_prey_births` policies.
#
# The other option is to update the `partial_state_update_blocks` by a list comprehension, like ``partial_state_update_blocks = [print_time(psub) for psub in partial_state_update_blocks]``. This is useful if you want to check everyone at once.

# %%
from time import time
import logging
from functools import wraps
logging.basicConfig(level=logging.DEBUG)

def print_time(f):
  """

  """
  @wraps(f)
  def wrapper(*args, **kwargs):
      # Current timestep
      t = len(args[2])
      t1 = time()
      f_out = f(*args, **kwargs)
      t2 = time()
      text = f"{t}|{f.__name__} output (exec time: {t2 - t1:.2f}s): {f_out}"
      logging.debug(text)
      return f_out
  return wrapper

# %% [markdown]
# ## Dependences

# %%
# %%capture
# !pip install cadcad

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from cadCAD.configuration import Experiment
from cadCAD.configuration.utils import config_sim
from cadCAD.engine import ExecutionMode, ExecutionContext, Executor

# %% [markdown]
# ## Definitions

# %% [markdown]
# ### Initial conditions and parameters

# %%
initial_conditions = {
    'prey_population': 100,
    'predator_population': 15
    }

params = {
    "prey_birth_rate": [1.0],
    "predator_birth_rate": [0.01],
    "predator_death_const": [1.0],
    "prey_death_const": [0.03],
    "dt": [0.1] # Precision of the simulation. Lower is more accurate / slower
}

simulation_parameters = {
    'N': 1,
    'T': range(30),
    'M': params
}

# %% [markdown]
# ### Policies

# %%
@print_time
def p_predator_births(params, step, sL, s):
  dt = params['dt']
  predator_population = s['predator_population']
  prey_population = s['prey_population']
  birth_fraction = params['predator_birth_rate'] + np.random.random() * 0.0002
  births =  birth_fraction * prey_population * predator_population * dt
  return {'add_to_predator_population': births}

@print_time
def p_prey_births(params, step, sL, s):
  dt = params['dt']
  population = s['prey_population']
  birth_fraction = params['prey_birth_rate'] + np.random.random() * 0.1
  births =  birth_fraction * population * dt
  return {'add_to_prey_population': births}


def p_predator_deaths(params, step, sL, s):
  dt = params['dt']
  population = s['predator_population']
  death_rate = params['predator_death_const'] + np.random.random() * 0.005
  deaths = death_rate * population * dt
  return {'add_to_predator_population': -1.0 * deaths}


def p_prey_deaths(params, step, sL, s):
  dt = params['dt']
  death_rate = params['prey_death_const'] + np.random.random() * 0.1
  prey_population = s['prey_population']
  predator_population = s['predator_population']
  deaths = death_rate * prey_population * predator_population * dt
  return {'add_to_prey_population': -1.0 * deaths}

# %% [markdown]
# ### State update functions

# %%
def s_prey_population(params, step, sL, s, _input):
    y = 'prey_population'
    x = s['prey_population'] + _input['add_to_prey_population']
    return (y, x)


def s_predator_population(params, step, sL, s, _input):
    y = 'predator_population'
    x = s['predator_population'] + _input['add_to_predator_population']
    return (y, x)

# %% [markdown]
# ### State update blocks

# %%
partial_state_update_blocks = [
    { 
        'policies': {
            'predator_births': p_predator_births,
            'prey_births': p_prey_births,
            'predator_deaths': p_predator_deaths,
            'prey_deaths': p_prey_deaths,
        },
        'variables': {
            'predator_population': s_prey_population,
            'prey_population': s_predator_population
        }
    }
]

# %% [markdown]
# ### Configuration and Execution

# %%
sim_config = config_sim(simulation_parameters)

exp = Experiment()
exp.append_configs(sim_configs=sim_config, 
                   initial_state=initial_conditions,
                   partial_state_update_blocks=partial_state_update_blocks)


from cadCAD import configs
exec_mode = ExecutionMode()
exec_context = ExecutionContext(exec_mode.local_mode)
executor = Executor(exec_context=exec_context, configs=configs) 
(records, tensor_field, _) = executor.execute()
# Out:
# n': 14.275350764469767}
# DEBUG:root:137|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 2.412025199976302}
# DEBUG:root:137|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 12.816841169520988}
# DEBUG:root:138|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 2.265621539615294}
# DEBUG:root:138|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 11.915573833394193}
# DEBUG:root:139|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 2.232234007045967}
# DEBUG:root:139|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 11.1913281862834}
# DEBUG:root:140|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 2.180254954799276}
# DEBUG:root:140|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 11.405578737811215}
# DEBUG:root:141|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 2.058686682416584}
# DEBUG:root:141|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 10.428015777091131}
# DEBUG:root:142|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.932328121890997}
# DEBUG:root:142|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 9.783374761403477}
# DEBUG:root:143|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.6922646655808002}
# DEBUG:root:143|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 8.410584189445485}
# DEBUG:root:144|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.5042229534179186}
# DEBUG:root:144|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 7.835443897260034}
# DEBUG:root:145|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.432205300119398}
# DEBUG:root:145|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 7.795024670062815}
# DEBUG:root:146|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.2161769173071655}
# DEBUG:root:146|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 6.605202161476227}
# DEBUG:root:147|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.1809194445791533}
# DEBUG:root:147|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 6.977729001636812}
# DEBUG:root:148|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.100485432920007}
# DEBUG:root:148|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 6.748327795640652}
# DEBUG:root:149|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.997372114929397}
# DEBUG:root:149|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 5.915282237804053}
# DEBUG:root:150|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.9247953253991925}
# DEBUG:root:150|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 5.775970958828913}
# DEBUG:root:151|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.8771162008695521}
# DEBUG:root:151|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 5.999575997082805}
# DEBUG:root:152|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.8665429754222096}
# DEBUG:root:152|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 6.274116685488715}
# DEBUG:root:153|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.8002479755694799}
# DEBUG:root:153|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 5.696277934615956}
# DEBUG:root:154|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.7585154408024781}
# DEBUG:root:154|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 5.873012289620961}
# DEBUG:root:155|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.7088476444682281}
# DEBUG:root:155|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 5.634417263062766}
# DEBUG:root:156|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.712790730694938}
# DEBUG:root:156|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 5.963338165858103}
# DEBUG:root:157|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.6926516425049716}
# DEBUG:root:157|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 6.356096070979869}
# DEBUG:root:158|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.659041859913756}
# DEBUG:root:158|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 6.155056780189196}
# DEBUG:root:159|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.677257646600343}
# DEBUG:root:159|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 6.651666757499952}
# DEBUG:root:160|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.679599144937942}
# DEBUG:root:160|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 6.9041908772303975}
# DEBUG:root:161|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.682088759388545}
# DEBUG:root:161|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 7.043215195007864}
# DEBUG:root:162|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.6723687906289408}
# DEBUG:root:162|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 7.055651300544361}
# DEBUG:root:163|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0.6925297310068808}
# DEBUG:root:163|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 7.70774930531761}
# DEBUG:root:164|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 0
p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.9016194559498325}
# DEBUG:root:199|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 10.814903208104326}
# DEBUG:root:200|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.829389645749604}
# DEBUG:root:200|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 10.693419581623358}
# DEBUG:root:1|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.5169151626182824}
# DEBUG:root:1|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 10.660765170277218}
# DEBUG:root:2|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.5222845383830823}
# DEBUG:root:2|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 10.124274623107736}
# DEBUG:root:3|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.4552888097550727}
# DEBUG:root:3|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 9.630853513042924}
# DEBUG:root:4|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.3194322547773396}
# DEBUG:root:4|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 8.910969811567385}
# DEBUG:root:5|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.3148297227854826}
# DEBUG:root:5|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 8.838702655350506}
# DEBUG:root:6|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.3373754439696475}
# DEBUG:root:6|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 9.22688246073636}
# DEBUG:root:7|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.2916475195706845}
# DEBUG:root:7|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 9.038133226029498}
# DEBUG:root:8|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.1762795662882437}
# DEBUG:root:8|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 8.747631495521706}
# DEBUG:root:9|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.1520352092631638}
# DEBUG:root:9|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 8.745836883903682}
# DEBUG:root:10|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.1934650477507829}
# DEBUG:root:10|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 8.549426938395305}
# DEBUG:root:11|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.2328227191779888}
# DEBUG:root:11|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 9.082232910735863}
# DEBUG:root:12|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.1360390457230698}
# DEBUG:root:12|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 9.087464108049046}
# DEBUG:root:13|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.138544290296607}
# DEBUG:root:13|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 8.782772346623355}
# DEBUG:root:14|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.1724225341635968}
# DEBUG:root:14|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 9.307424182537172}
# DEBUG:root:15|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.1835678899871733}
# DEBUG:root:15|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 9.643818684612244}
# DEBUG:root:16|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.2128832974654475}
# DEBUG:root:16|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 9.409501299035046}
# DEBUG:root:17|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.253490875038415}
# DEBUG:root:17|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 9.642948153472414}
# DEBUG:root:18|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.2021122943314284}
# DEBUG:root:18|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 9.691995307882445}
# DEBUG:root:19|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.25292259377796}
# DEBUG:root:19|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 10.09402731650224}
# DEBUG:root:20|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.2940216106628415}
# DEBUG:root:20|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 10.907101177892287}
# DEBUG:root:21|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.322975723478273}
# DEBUG:root:21|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 10.888339767870798}
# DEBUG:root:22|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.3895959919309513}
# DEBUG:root:22|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 11.138326298367694}
# DEBUG:root:23|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.419222290981802}
# DEBUG:root:23|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 11.485559122195015}
# DEBUG:root:24|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.4027802061575843}
# DEBUG:root:24|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 11.451865028480428}
# DEBUG:root:25|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.3850756571076788}
# DEBUG:root:25|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 11.351248593341843}
# DEBUG:root:26|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.4461330135588584}
# DEBUG:root:26|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 11.15325029287798}
# DEBUG:root:27|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.4899641375375263}
# DEBUG:root:27|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 11.677429452778531}
# DEBUG:root:28|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.4657306154743577}
# DEBUG:root:28|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 10.837426427909548}
# DEBUG:root:29|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.4494498888635525}
# DEBUG:root:29|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 10.64200127288832}
# DEBUG:root:30|p_predator_births output (exec time: 0.00s): {'add_to_predator_population': 1.5263358869158672}
# DEBUG:root:30|p_prey_births output (exec time: 0.00s): {'add_to_prey_population': 11.04075367811312}
# Total execution time: 7.53s

# %% [markdown]
# ### Results

# %%
import plotly.express as px

# %%
df = pd.DataFrame(records)

fig = px.line(df,
              x=df.prey_population,
              y=df.predator_population,
              color=df.run.astype(str))

fig.show()
